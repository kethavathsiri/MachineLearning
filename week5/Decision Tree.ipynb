# %% [markdown]
# ## Decision Tree
#
# ## Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
#Load the data sets- train and test 
df=pd.read_csv("train_titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Look at top values of train data 
df=pd.read_csv("train_titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Print the column names of train data
df=pd.read_csv("train_titanic.csv")
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data

df = pd.read_csv("train_titanic.csv")
print("Train Data Dimensions:",df.shape)#survied dependent
# Out:
# Train Data Dimensions: (891, 12)

# %%
#Print the number of missing values in each column of train and test data

df = pd.read_csv("train_titanic.csv")
print("Missing values in each column of train :")
df.isnull().sum()
# Out:
# Missing values in each column of train :
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked
"""import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("train_titanic.csv")
#convert Sex using the Label Encoding
df['Sex']=df['Sex'].map({"male":0,"feamle":1})
# Encode 'Embarked' using Dummy Encoding (creates separate columns for 'C', 'Q', 'S')
df=pd.get_dummies(df,columns=["Embarked"],drop_first=True)
df.isnull().sum()

# Survived
plt.figure(figsize=(6, 4))
df["Survived"].value_counts().plot(kind="bar", color=["skyblue", "orange"], edgecolor="black")
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# Pclass
plt.figure(figsize=(6, 4))
df["Pclass"].value_counts().plot(kind="bar", color=["skyblue", "orange", "green"], edgecolor="black")
plt.title("Passenger Class Distribution")
plt.xlabel("Pclass (1 = Upper, 2 = Middle, 3 = Lower)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# Sex
plt.figure(figsize=(6, 4))
df["Sex"].value_counts().plot(kind="bar", color=["skyblue", "orange"], edgecolor="black")
plt.title("Gender Distribution")
plt.xlabel("Sex (0 = Male, 1 = Female)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# Embarked_Q
plt.figure(figsize=(6, 4))
df["Embarked_Q"].value_counts().plot(kind="bar", color=["skyblue", "orange"], edgecolor="black")
plt.title("Embarked at Queenstown")
plt.xlabel("Embarked_Q (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# Embarked_S
plt.figure(figsize=(6, 4))
df["Embarked_S"].value_counts().plot(kind="bar", color=["skyblue", "orange"], edgecolor="black")
plt.title("Embarked at Southampton")
plt.xlabel("Embarked_S (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()"""
df = pd.read_csv("train_titanic.csv")
sns.barplot(x='Pclass',y='Survived',data=df)
sns.barplot(x='Sex',y='Survived',data=df)
sns.barplot(x='Embarked',y='Survived',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
#Histogram of Age, Parch, Fare
#Age Histogram
'''df=pd.read_csv("train_titanic.csv")
plt.figure(figure=(15,5))
plt.subplot(1,3,1)
plt.hist(df["Age"].dropna(),bins=20,color="skyblue",edgecolor="black")
plt.xlabel("Age")
plt.ylabel("Frequency")

# Parch Histogram
plt.subplot(1, 3, 2)
plt.hist(df["Parch"], bins=10, color="lightcoral", edgecolor="black")
plt.title("Histogram of Parch")
plt.xlabel("Parch")
plt.ylabel("Frequency")

# Fare Histogram
plt.subplot(1, 3, 3)
plt.hist(df["Fare"], bins=20, color="lightgreen", edgecolor="black")
plt.title("Histogram of Fare")
plt.xlabel("Fare")
plt.ylabel("Frequency")

# Adjust layout and show plot
plt.tight_layout()
plt.show()'''
sns.histplot(x='Age',data=df)
plt.show()
sns.histplot(x='Parch',data=df)
plt.show()
sns.histplot(x='Fare',data=df)
plt.show()

# %%
#Plot histogram of age for survived and did not survived class
'''import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("train_titanic.csv")

# Drop NaN values in Age to avoid errors
df = df.dropna(subset=["Age"])

# Create histograms for survived and not survived passengers
plt.figure(figsize=(12, 5))

# Histogram for Not Survived (Survived = 0)
plt.hist(df[df["Survived"] == 0]["Age"], bins=20, alpha=0.7, color="red", edgecolor="black", label="Did Not Survive")

# Histogram for Survived (Survived = 1)
plt.hist(df[df["Survived"] == 1]["Age"], bins=20, alpha=0.7, color="green", edgecolor="black", label="Survived")

# Add labels and title
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age for Survived and Not Survived Passengers")
plt.legend()  # Show the legend
plt.show()'''
sns.histplot(x='Age',hue='Survived',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Count class and gender wise survival rate - plot with appropriate chart
"""import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Load dataset

df = pd.read_csv("train_titanic.csv")

# Calculate survival rate based on Pclass and Sex
survival_rates = df.groupby(["Pclass", "Sex"])["Survived"].mean().unstack()

# Plot a grouped bar chart
plt.figure(figsize=(8, 5))
survival_rates.plot(kind="bar", stacked=False, color=["skyblue", "salmon"], edgecolor="black")

# Add labels and title
plt.title("Survival Rate by Passenger Class & Gender")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.xticks(rotation=0)
plt.legend(title="Gender")
plt.ylim(0, 1)  # Survival rate ranges from 0 to 1
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()
#Age wise Distribution of Male and Female passengers
"""
#Count class and geder wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers
sns.barplot(x='Sex',y='Pclass',hue='Survived',data=df)
plt.show()
sns.barplot(x='Age',hue='Sex',data=df)
plt.show()

# %%
#Histogram of Age of the given data set(sample)
"""import pandas as pd
import matplotlib.pyplot as plt

# Load dataset

df = pd.read_csv("train_titanic.csv")

# Drop missing Age values
df = df.dropna(subset=["Age"])

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black", alpha=0.7)

# Add labels and title
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
#plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show plot
plt.show()"""
#Histogram of Age of the given data set(sample)
#sns.histplot(x='Age',data=df)
df["Age"].hist()
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace the missing values in Embarked column by 'S'
df=pd.read_csv("train_titanic.csv")
df["Embarked"]=df["Embarked"].fillna('S')
print(df["Embarked"].isnull().sum())
# Out:
# 0

# %%
#Impute the missing values in Fare column with median value
df=pd.read_csv("train_titanic.csv")
df["Fare"]=df["Fare"].fillna(df["Fare"].median())
print(df["Fare"].isnull().sum())
# Out:
# 0

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data

import pandas as pd
import numpy as np

# Load dataset

df = pd.read_csv("train_titanic.csv")

# Get mean and standard deviation of the existing Age values
mean_age = df["Age"].mean()
std_age = df["Age"].std()

# Count missing values in Age
num_missing = df["Age"].isnull().sum()

# Generate random ages with same mean and standard deviation
random_ages = np.random.normal(mean_age, std_age, num_missing)

# Replace missing Age values with generated random ages
df.loc[df["Age"].isnull(), "Age"] = random_ages

# Verify if missing values are replaced
print(df["Age"].isnull().sum())  # Should print 0
# Out:
# 0

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch + SibSp + 1
df = pd.read_csv("train_titanic.csv")
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

# Display the first few rows to verify the new column
df[["SibSp", "Parch", "FamilySize"]].head()
# Out:
#    SibSp  Parch  FamilySize
# 0      1      0           2
# 1      1      0           2
# 2      0      0           1
# 3      1      0           2
# 4      0      0           1

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
df["IsAlone"] = df["FamilySize"] == 1

# Display the first few rows to verify the new column
df[["FamilySize", "IsAlone"]].head()
# Out:
#    FamilySize  IsAlone
# 0           2    False
# 1           2    False
# 2           1     True
# 3           2    False
# 4           1     True

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
df = pd.read_csv("train_titanic.csv")
df = df.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"], errors="ignore")


df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
# Define target variable (y)
df = pd.read_csv("train_titanic.csv")
y = df["Survived"]

# Define features (X) - exclude the target variable
X = df.drop(columns=["Survived"])

print(X.head())
print(y.head())
#X=df.iloc[:1,1:]
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
# Out:
# 0

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load dataset
df = pd.read_csv("train_titanic.csv")

# Encode 'Sex' using LabelEncoder
df['Sex'] = LabelEncoder().fit_transform(df['Sex'])

# One-Hot Encode 'Embarked' (excluding the first category to avoid dummy variable trap)
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True).replace({True:1,False:0})

# Display the relevant part of the processed DataFrame
print(df[['Sex', 'Embarked_Q', 'Embarked_S']].head())
# Out:
#    Sex  Embarked_Q  Embarked_S
# 0    1           0           1
# 1    0           0           0
# 2    0           0           1
# 3    0           0           1
# 4    1           0           1

# %%
# concat df_categorical with original df



# Drop the original 'Sex' and 'Embarked' columns from the original df
df_processed = df.drop(columns=['Sex', 'Embarked'], errors='ignore')

# Concatenate the processed categorical columns
df_final = pd.concat([df_processed, df], axis=1)

print("Final DataFrame:")
#print(df_final.head())
df_final.head()

df_final.isnull().sum()
# Out:
# Final DataFrame:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked_Q       0
# Embarked_S       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked_Q       0
# Embarked_S       0
# dtype: int64

# %%
#Do a pairplot of all features

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("train_titanic.csv")

# Encode categorical features before plotting
from sklearn.preprocessing import LabelEncoder

# Copy data and encode 'Sex'
df_encoded = df.copy()
df_encoded["Sex"] = LabelEncoder().fit_transform(df_encoded["Sex"])

# One-Hot Encoding for 'Embarked'
df_encoded = pd.get_dummies(df_encoded, columns=["Embarked"], drop_first=True)

# Drop non-numeric columns (like Name, Ticket, Cabin, PassengerId)
df_encoded = df_encoded.select_dtypes(include=["number"])

# Plot pairplot
sns.pairplot(df_encoded, hue="Survived", diag_kind="kde")
plt.show()

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split

# Define features (X) and target variable (y)
X = df.drop(columns=["Survived"])  # Features
y = df["Survived"]  # Target variable

# Drop non-numeric columns
X = X.drop(columns=["Name", "Ticket", "Cabin"], errors="ignore")

# Encode categorical variables
X["Sex"] = LabelEncoder().fit_transform(X["Sex"])
X = pd.get_dummies(X, columns=["Embarked"], drop_first=True)  # One-Hot Encoding

# Split data (90% train, 10% validation)
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y
)

# %%
X_train.shape
# Out:
# (801, 9)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
# Import necessary library

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder



# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy="median")
X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X.columns)
X_validation = pd.DataFrame(imputer.transform(X_validation), columns=X.columns)

# Train the Decision Tree model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#Print the tree
# Importing required packages for visualization
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set figure size for better readability
plt.figure(figsize=(15, 8))

# Plot the decision tree
plot_tree(clf, feature_names=X.columns, class_names=["Not Survived", "Survived"], filled=True, rounded=True)

# Show the tree plot
plt.show()

# %%
# plotting tree with max_depth=3
plt.figure(figsize=(50, 30))

# Plot the tree with max_depth=3
plot_tree(clf, feature_names=X.columns, class_names=["Not Survived", "Survived"], 
          filled=True, rounded=True, max_depth=3)

# Show the tree plot
plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
# Confusion Matrix
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Make Predictions
y_pred = clf.predict(X_validation)

# Confusion Matrix
cm = confusion_matrix(y_validation, y_pred)
print("Confusion Matrix:\n", cm)

# Plot Confusion Matrix for better visualization
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=["Not Survived", "Survived"], 
            yticklabels=["Not Survived", "Survived"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

# Accuracy
accuracy = accuracy_score(y_validation, y_pred)

# Classification Report (Precision, Recall, F1-score)
print("Classification Report:\n", classification_report(y_validation, y_pred))

print(f"Accuracy: {accuracy:.2f}")
# Out:
# Confusion Matrix:
#  [[47  8]
#  [ 6 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        55
#            1       0.78      0.83      0.81        35
#
#     accuracy                           0.84        90
#    macro avg       0.84      0.84      0.84        90
# weighted avg       0.85      0.84      0.85        90
#
# Accuracy: 0.84

# %%
# Printing confusion matrix and accuracy

from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# Make Predictions
y_pred = clf.predict(X_validation)

# Confusion Matrix
cm = confusion_matrix(y_validation, y_pred)
print("Confusion Matrix:\n", cm)

# Plot Confusion Matrix for better visualization
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=["Not Survived", "Survived"], 
            yticklabels=["Not Survived", "Survived"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Accuracy Score
accuracy = accuracy_score(y_validation, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Confusion Matrix:
#  [[47  8]
#  [ 6 29]]
# Accuracy: 0.84
